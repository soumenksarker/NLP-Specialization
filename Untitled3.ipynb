# %%
count=0 
while(mat[2][2] != '1'):
  if(s==2 and n!=2):
    if (n<2):
      e=mat[:][n+1] 
      mat[:][n+1]=mat[:][n] 
      mat[:][n]=e 
      count=count+1
    else:
      f=mat[:][n-1]
      mat[:][n-1]=mat[:][n]
      mat[:][n]=f 
      count=count+1 
  if(s!=2 and n==2):
    if(s<2):
      g=mat[s+1][:]
      mat[s+1][:]=mat[s][:]
      mat[s][:]=g 
      count=count + 1
    else:
      h=mat[s-1][:]
      mat[s-1][:]=mat[s][:]
      mat[s][:]=h 
      count = count + 1
  if(s!=2 and n!=2):
    if(s>2):
      a = mat[s-1][:]
      mat[s-1][:]=mat[s][:]
      mat[s][:]=a
      count=count + 1
    if(s<2):
      b = mat[s+1][:]
      mat[s + 1][:] = mat[s][:] 
      mat[s][:] = b
      count = count + 1
    if(n>2):
      c = mat[:][n-1]
      mat[:][n - 1] = mat[:][n]
      mat[:][n] = c
      count = count + 1
    if(n<2):
      d=mat[:][n+1]
      mat[:][n + 1] = mat[:][n] 
      mat[:][n] = d 
      count = count + 1
print(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a9bb8053e192> in <module>()
#       1 count=0
# ----> 2 while(mat[2][2] != '1'):
#       3   if(s==2 and n!=2):
#       4     if (n<2):
#       5       e=mat[:][n+1]
#
# NameError: name 'mat' is not defined
